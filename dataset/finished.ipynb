# %%
import pandas as pd
import numpy as np
import chardet
import ast

# %%
with open("cleaned.csv", "rb") as f:
    result = chardet.detect(f.read(100_000))

result

df = pd.read_csv("cleaned.csv", encoding=result["encoding"])

# %%
df
# Out:
#                                         name  rating                 category  \
# 0                    Pineapple Glaze for Ham     4.5               ['Dinner']
# 1                          Awesome Egg Rolls     4.5  ['Dinner', 'Appetizer']
# 2                           Spanish Tortilla     4.3            ['Breakfast']
# 3              Spicy Tarragon Yogurt Chicken     4.5               ['Dinner']
# 4                                Apple Bread     4.7               ['Brunch']
# ...                                      ...     ...                      ...
# 50508                    Huge Cinnamon Rolls     5.0            ['Breakfast']
# 50509                  Spicy Salmon Marinade     NaN               ['Dinner']
# 50510  Lemon Icebox Pie with Frozen Lemonade     4.0              ['Dessert']
# 50511                  Easy Shrimp Chow Mein     3.0               ['Dinner']
# 50512                Garlic-Smashed Potatoes     3.5  ['Dinner', 'Side Dish']
#
# ...

# %%
df.iloc[867]
# Out:
# name                              Linguini with Roasted Broccoli Pesto
# rating                                                             4.5
# category                                           ['Dinner', 'Pasta']
# cuisine                                                    ['Italian']
# ingredients          ['0.5 (16 ounce) package linguine pasta', '1 l...
# instructions         ['Bring a large pot of lightly salted water to...
# methods                                     ['bake', 'boil', 'reduce']
# utensils                     ['baking dish', 'skillet', 'oven', 'pot']
# servings                                           ['2', '2 servings']
# time                                                              45.0
# time_class                                                     average
# calories_kcal                                                   1121.0
# carbohydrates_g                                                  108.0
# ...
